# %% [markdown]
# ### Label Encoding is process of converting categorical label into numbers i.e. male = 0 & female = 1

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('/Users/jeettrivedi/Desktop/Data Science/Data Pre-Processing/Data/data.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# #### load the label encoder

# %%
label_encode = LabelEncoder()

# %%
labels = LabelEncoder().fit_transform(df.diagnosis)

# %% [markdown]
# #### appending labels to dataframe

# %%
df['target'] = labels
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df['target'].value_counts()
# Out:
# 0    357
# 1    212
# Name: target, dtype: int64

# %%
iris = pd.read_csv('/Users/jeettrivedi/Desktop/Data Science/Data Pre-Processing/Data/iris_data.csv')

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# ### Manual Label Encoding

# %%
iris['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
iris['Species'].replace('Iris-setosa' ,0, inplace=True)
iris['Species'].replace('Iris-versicolor' ,1, inplace=True)
iris['Species'].replace('Iris-virginica' ,2, inplace=True)
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]

# %%
iris['Species'].value_counts()
# Out:
# 0    50
# 1    50
# 2    50
# Name: Species, dtype: int64

# %% [markdown]
# # <i>This is for interview question</i>

# %%
print(f'{iris.dtypes} \n')
print(f'{iris.dtypes.value_counts()} \n')

# Get only columns with datatype of float64

iris.select_dtypes(include=['float64'])
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object
#
# float64    4
# int64      1
# object     1
# dtype: int64
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# ...

# %%
iris.sample(n=40)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 107  108            7.3           2.9            6.3           1.8
# 74    75            6.4           2.9            4.3           1.3
# 141  142            6.9           3.1            5.1           2.3
# 140  141            6.7           3.1            5.6           2.4
# 78    79            6.0           2.9            4.5           1.5
# 25    26            5.0           3.0            1.6           0.2
# 126  127            6.2           2.8            4.8           1.8
# 136  137            6.3           3.4            5.6           2.4
# 122  123            7.7           2.8            6.7           2.0
# 27    28            5.2           3.5            1.5           0.2
# 41    42            4.5           2.3            1.3           0.3
# 70    71            5.9           3.2            4.8           1.8
# 71    72            6.1           2.8            4.0           1.3
# ...

# %%
a = ['Jeet','Dev','Ajay']
b = ['Trivedi','Raval','Pandey']
b = [' ' + x  for x in b]
c = []
for i in range(len(a)):
    print(a[i])
    print(b[i])
    c.append(a[i]+b[i])
    
c
# Out:
# Jeet
#  Trivedi
# Dev
#  Raval
# Nidhi
#  Pandey
# ['Jeet Trivedi', 'Dev Raval', 'Nidhi Pandey']

# %%
a = ['Jessy','Donald','Nela']
b = ['Robert','Trump','Hunt']
c= []
for i,j in zip(a,b):
    name = i+' '+j
    c.append(name)

c
# Out:
# ['Jessy Robert', 'Donald Trump', 'Nela Hunt']
